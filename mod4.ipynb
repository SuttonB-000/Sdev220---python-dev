# %%
#11.1
#zoo.py
def hours(): 
    print(' Open 9-5 Daily')

# %%
hours()
# Out:
#  Open 9-5 Daily

# %%
#11.2
menagerie = hours()
menagerie
# Out:
#  Open 9-5 Daily

# %%
# 16.3 
# creating a csv file that can be used in 16.5

import csv

data = [
    ['title', 'author', 'year'],
    ['The Weirdstone of Brisingamen', 'Alan Garner', 1960],
    ['Perdid Street Station', 'China Mieville', 2000],
    ['Thud!', 'Terry Pratchett', 2005],
    ['The Spellman Files', 'Lisa Lutz', 2007],
    ['Small Gods', 'Terry Pratchett', 1992]
]

with open ('books2.csv', 'w', newline="") as file:
    writer = csv.writer(file)
    writer.writerows(data)

# %%
#16.4
import sqlite3

connection = sqlite3.connect('books.db')
cursor = connection.cursor()

cursor.execute("""
    CREATE TABLE books (
        title TEXT,
        author TEXT,
        year INTEGER
    )
""")

# %%
# 16.5 
# reading books2,csv file into books db and table

import sqlite3
import csv

connection = sqlite3.connect('books.db')
cursor = connection.cursor()

with open('books2.csv', 'r', newline="") as file:
    reader = csv.DictReader(file)

    for row in reader:
        cursor.execute(
            '''
            INSERT INTO books (title, author, year)
            VALUES (?,?,?)
            ''',
            (row['title'], row['author'], row['year'])
        )
connection.commit()

connection.close()

# %%
# 16.8 
# use SQLAlchemy to present the title column from books.db

from sqlalchemy import create_engine, select
from sqlalchemy.orm import DeclarativeBase, Session
from sqlalchemy import Column, Integer, String

#Base class for models
class Base(DeclarativeBase):
    pass

#define table metadata?
class books(Base):
    __tablename__ = "books"

    title = Column(String, primary_key=True)
    author = Column(String)
    year = Column(Integer)

#create engine TODO: what be an engine, dawg?
engine = create_engine("sqlite:///books.db")

# Create Session --> session is the way python interacts with db, like cursor 
with Session(engine) as session:

    #query thine db
    statement = select(books.title)

    #gimme that data from each row
    titles = session.scalars(statement)

    for title in titles:
        print(title)
# Out:
# The Weirdstone of Brisingamen
# Perdid Street Station
# Thud!
# The Spellman Files
# Small Gods

# %%
print("I FIGURED IT OUTTTTT")
# Out:
# I FIGURED IT OUTTTTT
