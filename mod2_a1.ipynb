# %%
#4.1
secret = 2
guess = 5

if guess > secret:
    print('Too High')
elif guess < secret:
    print('Too Low')
else:
    print('Just Right')
# Out:
# Too High

# %%
#4.2
watermelon = 'green'
if watermelon == 'green':
    print(True)
else:
    print(false)

cherry = 'red'
if cherry == 'green':
    print(True)
else:
    print(False)

pumpkin = 'orange'
if pumpkin == 'green':
    print(True)
else:
    print(False)

pea = 'small'
if pea == 'small':
    print(True)
else:
    print(False)
# Out:
# True
# False
# False
# True

# %%
# 6.1
my_list = [3,2,1,0]

for i in my_list:
    print(i)
# Out:
# 3
# 2
# 1
# 0

# %%
# 6.2 

guess_me = 7
number = 1

while number != guess_me:
    number += 1
    if number < guess_me:
        print('Too low')
    elif number == guess_me: 
        print('found it')
    else:
        print('Oops too high:')
# Out:
# Too low
# Too low
# Too low
# Too low
# Too low
# found it

# %%
# 6.3

guess_me = 5

for number in range(10):
    if number < guess_me:
        print("Too low")
    elif number == guess_me:
        print("Found it!")
        break
    else:
        print("oops")
# Out:
# Too low
# Too low
# Too low
# Too low
# Too low
# Found it!
