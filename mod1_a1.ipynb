# %%
minutes_in_hour = 60
seconds_in_minute = 60
seconds_in_hour = minutes_in_hour * seconds_in_minute

print(seconds_in_hour)
# Out:
# 3600

# %%
hours_in_day = 24
seconds_in_day = seconds_in_hour * hours_in_day

print(seconds_in_day)
# Out:
# 86400

# %%
hours = seconds_in_day / seconds_in_hour

print(hours)

hours = seconds_in_day // seconds_in_hour

print(hours)
# Out:
# 24.0
# 24

# %%
print("3.6 question answer, yeah they agreed")
# Out:
# 3.6 question answer, yeah they agreed
